# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import sys
caffe_root = '/home/ambika/caffe/'  # this file should be run from {caffe_root}/examples (otherwise change this line)
sys.path.insert(0, caffe_root + 'python')

import caffe
# %matplotlib inline

data_path='/home/ambika/INF_project/augmented_labels_all.txt'
data = np.loadtxt(data_path, str, delimiter='\t')

#print len(data)
#print data[0]
#print data[0][0]
#print data[0][1]
#print data[0][2]
#print data[0][3]
#print data[0][4]
#print data[0][5]
#print data[0][6]
#print data[0][7]
#print data[0][8]
#print data[0][9]
#print data[0][10]

#for i in range(0,99):
i=1
image = plt.imread('/'+data[i][0])
    
print data[i][1]
print data[i][2]
print data[i][3]
print data[i][4]
print data[i][5]
print data[i][6]
print data[i][7]
print data[i][8]
print data[i][9]
print data[i][10]
plt.imshow(image)
# Out:
# odd-toed_ungulate
# 0.160899
# hunting_dog
# 0.145021
# hunting_dog
# 0.108573
# canine
# 0.0877703
# canine
# 0.0828095

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import sys
caffe_root = '/home/ambika/caffe/'  # this file should be run from {caffe_root}/examples (otherwise change this line)
sys.path.insert(0, caffe_root + 'python')

import caffe
# %matplotlib inline

data_path='/home/ambika/INF_project/augmented_one_level_labels_all.txt'
data = np.loadtxt(data_path, str, delimiter='\t')

#print len(data)
#print data[0]
#print data[0][0]
#print data[0][1]
#print data[0][2]
#print data[0][3]
#print data[0][4]
#print data[0][5]
#print data[0][6]
#print data[0][7]
#print data[0][8]
#print data[0][9]
#print data[0][10]

#for i in range(0,99):
i=98
image = plt.imread('/'+data[i][0])
    
print data[i][1]
print data[i][2]
print data[i][3]
print data[i][4]
print data[i][5]
print data[i][6]
print data[i][7]
print data[i][8]
print data[i][9]
print data[i][10]
plt.imshow(image)
# Out:
# finch
# 0.248659
# finch
# 0.210292
# nightingale
# 0.152477
# finch
# 0.136504
# finch
# 0.0905828

# %%
d=list(data[0][1:])
print d
t=[data[0][1],data[0][3],data[0][5],data[0][7],data[0][9]]
print t
t2=list(set(t))
print t2
final=[]
for u in range(0,len(t2)):
    ind=[]
    for v in range(0,len(d)):
        if t2[u]==d[v]:
            ind.append(v)
            print ind
    prob=0
    for w in range(0,len(ind)):
        prob=prob+float(d[ind[w]+1])
        print prob
    final.append(t2[u])
    final.append(str(prob))
    
print final
# Out:
# ['game_equipment', '0.5036', 'structure', '0.100293', 'game_equipment', '0.0852196', 'structure', '0.0440295', 'building', '0.0344064']
# ['game_equipment', 'structure', 'game_equipment', 'structure', 'building']
# ['building', 'game_equipment', 'structure']
# [8]
# 0.0344064
# [0]
# [0, 4]
# 0.5036
# 0.5888196
# [2]
# [2, 6]
# 0.100293
# 0.1443225
# ['building', '0.0344064', 'game_equipment', '0.5888196', 'structure', '0.1443225']
