# %%
import nltk
import csv
import numpy as np
from nltk.corpus import wordnet

s=wordnet._synset_from_pos_and_offset('n',4543158)
print s
h1=s.hyponyms()
print h1
h2=s.hypernyms()
print h2
# Out:
# Synset('wagon.n.01')
# [Synset('bandwagon.n.02'), Synset('cart.n.01'), Synset('chuck_wagon.n.01'), Synset('covered_wagon.n.01'), Synset('ice_wagon.n.01'), Synset('lorry.n.01'), Synset('milk_wagon.n.01'), Synset('tramcar.n.01'), Synset('wain.n.03'), Synset('water_wagon.n.01')]
# [Synset('wheeled_vehicle.n.01')]

# %%
test_labels='/home/ambika/INF_project/test_labels.txt'
labels = np.loadtxt(test_labels, str, delimiter='\t')
#print labels[1]

filename='augmented_labels.txt'
b = open(filename, 'wb') 
a = csv.writer(b)
for i in range(0,10):
    data=[]
    for j in range(2,12,2):
        if j==10:
            x=labels[i][j][1:10]
        else:
            x=labels[i][j][1:10]
        s=wordnet._synset_from_pos_and_offset('n',int(x))
        h=s.hypernyms()
        h2=h[0].hypernyms()
        h3=h2[0].hypernyms()
        #print s
        print h
        print h2
        print h3
        #print h[0].lemmas()[0].name()
        y=h3[0].lemmas()[0].name()
        data.append(y)
    
    var=labels[i][0][1:]+'\t'+data[0]+'\t'+labels[i][1]+'\t'+data[1]+'\t'+labels[i][3]+'\t'+data[2]+'\t'+labels[i][5]+'\t'+data[3]+'\t'+labels[i][7]+'\t'+data[4]+'\t'+labels[i][9]
    print var
    a.writerows([[var]])
    
b.close()
# Out:
# [Synset('puzzle.n.02')]
# [Synset('game.n.09')]
# [Synset('game_equipment.n.01')]
# [Synset('fortification.n.01')]
# [Synset('defensive_structure.n.01')]
# [Synset('structure.n.01')]
# [Synset('puzzle.n.02')]
# [Synset('game.n.09')]
# [Synset('game_equipment.n.01')]
# [Synset('farm_building.n.01')]
# [Synset('building.n.01')]
# [Synset('structure.n.01')]
# [Synset('residence.n.02')]
# [Synset('house.n.01')]
# [Synset('building.n.01'), Synset('dwelling.n.01')]
# /home/ambika/Downloads/CrowdSourcing-Project-master/samples/26201.jpg	game_equipment	0.5036	structure	0.100293	game_equipment	0.0852196	structure	0.0440295	building	0.0344064
# [Synset('horse.n.01')]
# [Synset('equine.n.01')]
# [Synset('odd-toed_ungulate.n.01')]
# [Synset('bullterrier.n.01')]
# [Synset('terrier.n.01')]
# [Synset('hunting_dog.n.01')]
# [Synset('bullterrier.n.01')]
# [Synset('terrier.n.01')]
# [Synset('hunting_dog.n.01')]
# [Synset('working_dog.n.01')]
# [Synset('dog.n.01')]
# [Synset('canine.n.02'), Synset('domestic_animal.n.01')]
# [Synset('working_dog.n.01')]
# [Synset('dog.n.01')]
# [Synset('canine.n.02'), Synset('domestic_animal.n.01')]
# /home/ambika/Downloads/CrowdSourcing-Project-master/samples/23033.jpg	odd-toed_ungulate	0.160899	hunting_dog	0.145021	hunting_dog	0.108573	canine	0.0877703	canine	0.0828095
# [Synset('thrush.n.03')]
# [Synset('oscine.n.01')]
# [Synset('passerine.n.01')]
# [Synset('finch.n.01')]
# [Synset('oscine.n.01')]
# [Synset('passerine.n.01')]
# [Synset('nightingale.n.01')]
# [Synset('thrush.n.03')]
# [Synset('oscine.n.01')]
# [Synset('phasianid.n.01')]
# [Synset('game_bird.n.01')]
# [Synset('gallinaceous_bird.n.01'), Synset('game.n.04')]
# [Synset('cuckoo.n.02')]
# [Synset('cuculiform_bird.n.01')]
# [Synset('bird.n.01')]
# /home/ambika/Downloads/CrowdSourcing-Project-master/samples/41867.jpg	passerine	0.94512	passerine	0.0329558	oscine	0.00390311	gallinaceous_bird	0.00390274	bird	0.00348822
# [Synset('plaything.n.01')]
# [Synset('artifact.n.01')]
# [Synset('whole.n.02')]
# [Synset('lantern.n.01')]
# [Synset('lamp.n.01')]
# [Synset('source_of_illumination.n.01')]
# [Synset('percussion_instrument.n.01')]
# [Synset('musical_instrument.n.01')]
# [Synset('device.n.01')]
# [Synset('safety_belt.n.01')]
# [Synset('belt.n.02'), Synset('restraint.n.06')]
# [Synset('accessory.n.01')]
# [Synset('stringed_instrument.n.01')]
# [Synset('musical_instrument.n.01')]
# [Synset('device.n.01')]
# /home/ambika/Downloads/CrowdSourcing-Project-master/samples/1404.jpg	whole	0.409742	source_of_illumination	0.2539	device	0.0756896	accessory	0.0382077	device	0.0150836
# [Synset('runner.n.09')]
# [Synset('device.n.01')]
# [Synset('instrumentality.n.03')]
# [Synset('coat.n.01')]
# [Synset('overgarment.n.01')]
# [Synset('garment.n.01')]
# [Synset('poodle.n.01')]
# [Synset('dog.n.01')]
# [Synset('canine.n.02'), Synset('domestic_animal.n.01')]
# [Synset('wheeled_vehicle.n.01')]
# [Synset('container.n.01'), Synset('vehicle.n.01')]
# [Synset('instrumentality.n.03')]
# [Synset('water_spaniel.n.01')]
# [Synset('spaniel.n.01')]
# [Synset('sporting_dog.n.01')]
# /home/ambika/Downloads/CrowdSourcing-Project-master/samples/1700.jpg	instrumentality	0.27689	garment	0.232415	canine	0.0718764	instrumentality	0.0450113	sporting_dog	0.0422029
# [Synset('bus.n.01')]
# [Synset('public_transport.n.01')]
# [Synset('conveyance.n.03')]
# [Synset('car.n.01')]
# [Synset('motor_vehicle.n.01')]
# [Synset('self-propelled_vehicle.n.01')]
# [Synset('cavy.n.01')]
# [Synset('rodent.n.01')]
# [Synset('placental.n.01')]
# [Synset('light.n.14')]
# [Synset('visual_signal.n.01')]
# [Synset('signal.n.01')]
# [Synset('sharpener.n.01')]
# [Synset('implement.n.01')]
# [Synset('instrumentality.n.03')]
# /home/ambika/Downloads/CrowdSourcing-Project-master/samples/32597.jpg	conveyance	0.0471858	self-propelled_vehicle	0.0380594	placental	0.0366355	signal	0.0329678	instrumentality	0.0232601
# [Synset('cabinet.n.01')]
# [Synset('furniture.n.01')]
# [Synset('furnishing.n.02')]
# [Synset('wall_unit.n.01')]
# [Synset('furniture.n.01')]
# [Synset('furnishing.n.02')]
# [Synset('theater.n.01')]
# [Synset('building.n.01')]
# [Synset('structure.n.01')]
# [Synset('door.n.01')]
# [Synset('movable_barrier.n.01')]
# [Synset('barrier.n.01')]
# [Synset('building.n.01')]
# [Synset('structure.n.01')]
# [Synset('artifact.n.01')]
# /home/ambika/Downloads/CrowdSourcing-Project-master/samples/49151.jpg	furnishing	0.391453	furnishing	0.0928668	structure	0.0850235	barrier	0.0619479	artifact	0.0407105
# [Synset('watchdog.n.02')]
# [Synset('working_dog.n.01')]
# [Synset('dog.n.01')]
# [Synset('table.n.02')]
# [Synset('furniture.n.01')]
# [Synset('furnishing.n.02')]
# [Synset('belgian_sheepdog.n.01')]
# [Synset('shepherd_dog.n.01')]
# [Synset('working_dog.n.01')]
# [Synset('heater.n.01')]
# [Synset('device.n.01')]
# [Synset('instrumentality.n.03')]
# [Synset('weight.n.02')]
# [Synset('sports_equipment.n.01')]
# [Synset('equipment.n.01')]
# home/ambika/Downloads/CrowdSourcing-Project-master/samples/22874.jpg	dog	0.266402	furnishing	0.0774871	working_dog	0.0545317	instrumentality	0.0522445	equipment	0.039357
# [Synset('hound.n.01')]
# [Synset('hunting_dog.n.01')]
# [Synset('dog.n.01')]
# [Synset('greyhound.n.01')]
# [Synset('hound.n.01'), Synset('racer.n.03')]
# [Synset('hunting_dog.n.01')]
# [Synset('hound.n.01')]
# [Synset('hunting_dog.n.01')]
# [Synset('dog.n.01')]
# [Synset('retriever.n.01')]
# [Synset('sporting_dog.n.01')]
# [Synset('hunting_dog.n.01')]
# [Synset('retriever.n.01')]
# [Synset('sporting_dog.n.01')]
# [Synset('hunting_dog.n.01')]
# home/ambika/Downloads/CrowdSourcing-Project-master/samples/22192.jpg	dog	0.287044	hunting_dog	0.117441	dog	0.102455	hunting_dog	0.0664362	hunting_dog	0.0544982
# [Synset('piano.n.01')]
# [Synset('keyboard_instrument.n.01'), Synset('percussion_instrument.n.01'), Synset('stringed_instrument.n.01')]
# [Synset('musical_instrument.n.01')]
# [Synset('ball.n.01')]
# [Synset('game_equipment.n.01')]
# [Synset('equipment.n.01')]
# [Synset('door.n.01')]
# [Synset('movable_barrier.n.01')]
# [Synset('barrier.n.01')]
# [Synset('screen.n.04')]
# [Synset('covering.n.02')]
# [Synset('artifact.n.01')]
# [Synset('chair.n.01')]
# [Synset('seat.n.03')]
# [Synset('furniture.n.01')]
# /home/ambika/Downloads/CrowdSourcing-Project-master/samples/86250.jpg	musical_instrument	0.0630393	equipment	0.0595356	barrier	0.052051	artifact	0.0267044	furniture	0.0255545

# %%
print h
# Out:
# [Synset('chair.n.01')]
