# %%
import nltk
import csv
import numpy as np
from nltk.corpus import wordnet as wn


test_labels='/home/ambika/INF_project/alexnet_labels_1000.txt'
labels = np.loadtxt(test_labels, str, delimiter='\t')

filename='alexnet_labels_filtered.txt'
b = open(filename, 'wb') 
a = csv.writer(b)
for i in range(0,1000):
    data=[]
    for j in range(2,12,2):
        x=labels[i][j][1:10]
        s=wn._synset_from_pos_and_offset('n',int(x))
        h=s.hypernyms()
        y=h[0].name()
        if y=='car.n.02':
            z='train'
        elif y=='car.n.01':
            z='car'
        else:
            z=h[0].lemmas()[0].name()
        if (z=='equine' or z=='horse' or z=='even-toed_ungulate' or z=='cart'):
            z='horse'
        elif (z=='coonhound' or z=='foxhound' or z=='Sennenhunde' or z=='fox_terrier' or z=='spaniel' or z=='mastiff' or z=='hunting_dog' or z=='bullterrier' or z=='working_dog' or z=='poodle' or z=='water_spaniel' or z=='watchdog' or z=='Belgian_sheepdog' or z=='hound' or z=='greyhound' or z=='retriever' or z=='setter' or z=='shepherd_dog' or z=='toy_dog' or z=='pinscher' or z=='wild_dog' or z=='sled_dog' or z=='corgi' or z=='wolfhound' or z=='spitz' or z=='canine' or z=='springer_spaniel' or z=='schnauzer' or z=='bulldog' or z=='terrier' or z=='dog' or z=='toy_spaniel' or z=='English_toy_spaniel'):
            z='dog'
        elif (z=='purple_gallinule' or z=='owl' or z=='cockatoo' or z=='eagle' or z=='piciform_bird' or z=='egret' or z=='oscine' or z=='heron' or z=='lory' or z=='titmouse' or z=='pelecaniform_seabird' or z=='parrot' or z=='pelagic_bird' or z=='peafowl' or z=='duck' or z=='merganser' or z=='snipe' or z=='swan' or z=='coot' or z=='shorebird' or z=='grouse' or z=='thrush' or z=='finch' or z=='nightingale' or z=='phasianid' or z=='cuckoo' or z=='hawk' or z=='coraciiform_bird' or z=='apodiform_bird' or z=='wading_bird' or z=='corvine_bird' or z=='anseriform_bird' or z=='stork' or z=='ratite' or z=='bird_of_prey'):
            z='bird'
        elif (z=='chair' or z=='convertible'):
            z='couch'
        elif (z=='locomotive' or z=='train' or z=='passenger_train'):
            z='train'
        elif (z=='self-propelled_vehicle' or z=='car'):
            z='car'
        elif (z=='wildcat' or z=='domestic_cat' or z=='big_cat'):
            z='cat'
        elif (z=='weapon' or z=='heavier-than-air_craft' or z=='lighter-than-air_craft' or z=='airliner' or z=='rescue_equipment'):
            z='airplane'
        elif (z=='athlete' or z=='participant'):
            z='person'
        elif (z=='minibike' or z=='wheeled_vehicle' or z=='bicycle'):
            z='bike'
        elif (z=='elephant' or z=='mammal'):
            z='elephant'
        elif (z=='runner'):
            z='ski'
        elif (z=='cavy'):
            z='guinea_pig'
        elif (z=='bar'):
            z='sandbar'
        elif (z=='spring'):
            z='water_body'
        elif (z=='theater' or z=='correctional_institution'):
            z='building'
        elif (z=='airfoil'):
            z='airplane_wing'
        elif (z=='telecommunication_system'):
            z='television'
        elif (z=='wall_unit'):
            z='entertainment_center'
        elif (z=='tracked_vehicle'):
            z='snowmobile'
        elif (z=='Old_World_buffalo'):
            z='buffalo'
        elif (z=='woodwind' or z=='free-reed_instrument' or z=='stringed_instrument' or z=='bowed_stringed_instrument' or z=='wind_instrument' or z=='double-reed_instrument' or z=='pipe' or z=='single-reed_instrument'):
            z='musical_instrument'
        elif (z=='sports_implement'):
            z='sports_equipment'
        elif (z=='leporid'):
            z='rabbit'
        elif (z=='lesser_ape' or z=='great_ape'):
            z='ape_like_animal'
        elif (z=='cleaning_implement'):
            z='cleaning_equipment'
        #elif (z=='canopy'):
            #z='trees'
        elif (z=='vessel' or z=='basin'):
            z='wash_basin'
        elif (z=='rack'):
            z='tripod'
        elif (z=='stew' or z=='entree'):
            z='dish'
        elif (z=='mountain_sheep'):
            z='sheep'
        elif (z=='cabinet' or z=='office_furniture'):
            z='furniture'
        elif (z=='motorboat' or z=='sailboat' or z=='sea_boat' or z=='small_boat' or z=='sailing_vessel'):
            z='boat'
        elif (z=='cistern'):
            z='reservoir'
        elif (z=='baleen_whale'):
            z='whale'
        elif (z=='passenger_ship' or z=='cargo_ship'):
            z='ship'
        elif (z=='plaything'):
            z='toy'
        elif (z=='phalanger'):
            z='tree_dwelling_animal'
        elif (z=='radiotelephone'):
            z='cellphone'
        elif (z=='decapod_crustacean' or z=='true_lobster'):
            z='lobster'
        elif (z=='canopy' or z=='trees' or z=='phasmid'):
            z=''
            labels[i][j-1]=''
        elif (z=='fare' or z=='sea_cow' or z=='Old_World_monkey' or z=='lemur' or z=='structure' or z=='griffon' or z=='procyonid' or z=='ligament' or z=='chordophone' or z=='hosiery' or z=='scorpaenid' or z=='arachnid' or z=='homopterous_insect' or z=='top' or z=='edge_tool' or z=='New_World_monkey' or z=='orthopterous_insect' or z=='armor_plate' or z=='turner' or z=='gastropod' or z=='pin' or z=='echinoderm' or z=='stick' or z=='odonate' or z=='food_fish' or z=='cloak' or z=='summer_squash' or z=='salmon' or z=='cyprinid' or z=='natural_depression' or z=='mackerel_shark' or z=='control' or z=='adhesive_bandage' or z=='cream' or z=='restraint' or z=='brace' or z=='duplicator' or z=='automatic_rifle' or z=='arch' or z=='hydraulic_brake' or z=='column' or z=='iguanid' or z=='platform' or z=='viverrine' or z=='winder' or z=='cyprinid' or z=='acarine' or z=='winter_squash' or z=='undergarment' or z=='area' or z=='machine' or z=='colubrid_snake' or z=='danaid' or z=='monotreme' or z=='receptacle' or z=='mechanical_device' or z=='optical_instrument' or z=='spoon' or z=='lock' or z=='ganoid' or z=='boot' or z=='litter' or z=='musteline_mammal' or z=='bunting' or z=='trees' or z=='ray' or z=='sharpener' or z=='cooker' or z=='diver' or z=='marsupial' or z=='wirehair' or z=='converging_lens' or z=='applicator' or z=='kernel' or z=='face_mask'):
            z=''
            labels[i][j-1]=''
        elif (z=='brass' or z=='electro-acoustic_transducer' or z=='shaker' or z=='sandpiper' or z=='turnstone' or z=='oilseed' or z=='punch' or z=='measure' or z=='gymnastic_apparatus' or z=='eared_seal' or z=='concoction' or z=='rocket' or z=='garden_tool' or z=='dictyopterous_insect' or z=='submersible' or z=='housing' or z=='disk' or z=='grate' or z=='handcart' or z=='chair_of_state' or z=='peripheral' or z=='warship' or z=='savings_bank' or z=='box' or z=='hand_tool' or z=='trees' or z=='fungus' or z=='pointer' or z=='safety_belt' or z=='trouser' or z=='gun' or z=='system' or z=='rod' or z=='wheel' or z=='trap' or z=='covering' or z=='arthropod' or z=='fastener' or z=='instrument_of_execution' or z=='spaghetti_sauce' or z=='timer' or z=='globule' or z=='motor_vehicle'or z=='cracker' or z=='drill_rig' or z=='barrier' or z=='bovid' or z=='staff' or z=='tool' or z=='protective_garment' or z=='mechanism' or z=='data_input_device' or z=='landing' or z=='support' or z=='ambystomid' or z=='breathing_device' or z=='oar' or z=='ceratopsian' or z=='van' or z=='percussion_instrument' or z=='white_goods' or z=='sauce' or z=='hymenopterous_insect' or z=='drill'):
            z=''
            labels[i][j-1]=''
        data.append(z)
    
    var=labels[i][0][1:]+'\t'+data[0]+'\t'+labels[i][1]+'\t'+data[1]+'\t'+labels[i][3]+'\t'+data[2]+'\t'+labels[i][5]+'\t'+data[3]+'\t'+labels[i][7]+'\t'+data[4]+'\t'+labels[i][9]
    print var
    a.writerows([[var]])
    
b.close()
# Out:
# /home/ambika/INF_project/data/airplane/144114.jpg	airplane_wing	0.426471	airplane	0.282208	airplane	0.278781	spacecraft	0.00393522
# /home/ambika/INF_project/data/bird/388902.jpg	heater	0.0590619	kitchen_appliance	0.0330702	rail_fence	0.0317791	window_blind	0.0290973
# /home/ambika/INF_project/data/bus/171298.jpg			truck	0.19835	truck	0.119671	bus	0.0945696	car	0.077826
# /home/ambika/INF_project/data/car/126260.jpg	truck	0.181286			car	0.113338	truck	0.0856184	car	0.0770581
# /home/ambika/INF_project/data/cat/223626.jpg			dog	0.101685			ski	0.0577287
# /home/ambika/INF_project/data/couch/422886.jpg	frozen_dessert	0.225453			sandwich	0.180575	hamburger	0.125972	cap	0.0778248
# home/ambika/INF_project/data/dog/362219.jpg	mug	0.454934			coffee	0.0391076			pot	0.0101193
# /home/ambika/INF_project/data/horse/26201.jpg	puzzle	0.5036	fortification	0.100293	puzzle	0.0852196	farm_building	0.0440295	residence	0.0344064
# ...

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import sys
caffe_root = '/home/ambika/caffe/'  # this file should be run from {caffe_root}/examples (otherwise change this line)
sys.path.insert(0, caffe_root + 'python')

import caffe
# %matplotlib inline

data_path='/home/ambika/INF_project/alexnet_labels_filtered.txt'
data = np.loadtxt(data_path, str, delimiter='\t')

i=0
image = plt.imread('/'+data[i][0])
    
print data[i][1]
print data[i][2]
print data[i][3]
print data[i][4]
print data[i][5]
print data[i][6]
print data[i][7]
print data[i][8]
print data[i][9]
print data[i][10]
plt.imshow(image)
# Out:
# bridge
# 0.528068
#
#
# building
# 0.0269631

# %%
import nltk
import csv
import numpy as np
from nltk.corpus import wordnet as wn

test_labels='/home/ambika/INF_project/test_labels_all.txt'
labels = np.loadtxt(test_labels, str, delimiter='\t')

print labels[0]
print labels[0][0]
print labels[0][1]
print labels[0][2]

x=labels[1][2][1:10]
print x

s=wn._synset_from_pos_and_offset('n',int(x))
print s
h=s.hypernyms()
print h
y=h[0].name()
print y

if y=='puzzle.n.02':
    print 'yes'
else:
    print 'no'

for i in range(2,12,2):
    print i
# Out:
# ['"/home/ambika/Downloads/CrowdSourcing-Project-master/samples/26201.jpg'
#  '0.5036' 'n03598930 jigsaw puzzle' '0.100293' 'n02980441 castle'
#  '0.0852196' 'n06785654 crossword puzzle, crossword' '0.0440295'
#  'n02793495 barn' '0.0344064' 'n03877845 palace"']
# "/home/ambika/Downloads/CrowdSourcing-Project-master/samples/26201.jpg
# 0.5036
# n03598930 jigsaw puzzle
# 02389026
# Synset('sorrel.n.05')
# [Synset('horse.n.01')]
# horse.n.01
# no
# 2
# 4
# 6
# 8
# 10

# %%
data_path='/home/ambika/INF_project/alexnet_labels_filtered.txt'
data = np.loadtxt(data_path, str, delimiter='\t')

filename='alexnet_labels_final.txt'
b = open(filename, 'wb') 
a = csv.writer(b)

for i in range(0,1000):
    d=list(data[i][1:])
    #print d
    t=[data[i][1],data[i][3],data[i][5],data[i][7],data[i][9]]
    #print t
    t2=list(set(t))
    #print t2
    if '' in t2:
        t2.remove('')
    #print t2
    final=[]
    for u in range(0,len(t2)):
        ind=[]
        for v in range(0,len(d)):
            if t2[u]==d[v]:
                ind.append(v)
                #print ind
            prob=0
            for w in range(0,len(ind)):
                prob=prob+float(d[ind[w]+1])
        #print prob
        final.append(t2[u])
        final.append(str(prob))
    
    print final
    var2=data[i][0]
    for j in range(len(final)):
        var2+='\t'+final[j]
    print var2
    a.writerows([[var2]])

b.close()
# Out:
# ['airplane_wing', '0.426471', 'airplane', '0.560989', 'spacecraft', '0.00393522']
# /home/ambika/INF_project/data/airplane/144114.jpg	airplane_wing	0.426471	airplane	0.560989	spacecraft	0.00393522
# ['rail_fence', '0.0317791', 'heater', '0.0590619', 'window_blind', '0.0290973', 'kitchen_appliance', '0.0330702']
# /home/ambika/INF_project/data/bird/388902.jpg	rail_fence	0.0317791	heater	0.0590619	window_blind	0.0290973	kitchen_appliance	0.0330702
# ['bus', '0.0945696', 'truck', '0.318021', 'car', '0.077826']
# /home/ambika/INF_project/data/bus/171298.jpg	bus	0.0945696	truck	0.318021	car	0.077826
# ['car', '0.1903961', 'truck', '0.2669044']
# /home/ambika/INF_project/data/car/126260.jpg	car	0.1903961	truck	0.2669044
# ['ski', '0.0577287', 'dog', '0.101685']
# /home/ambika/INF_project/data/cat/223626.jpg	ski	0.0577287	dog	0.101685
# ['cap', '0.0778248', 'sandwich', '0.180575', 'hamburger', '0.125972', 'frozen_dessert', '0.225453']
# ...

# %%
d=list(data[97][1:])
print d
t=[data[97][1],data[97][3],data[97][5],data[97][7],data[97][9]]
print t
t2=list(set(t))
print t2
t2.remove('')
print t2
# Out:
# ['airplane', '0.397763', 'airplane wing', '0.0642287', 'airplane', '0.0530834', '', '', '', '']
# ['airplane', 'airplane wing', 'airplane', '', '']
# ['', 'airplane', 'airplane wing']
# ['airplane', 'airplane wing']

# %%
import json
data_path='/home/ambika/INF_project/alexnet_labels_final.txt'

with open(data_path) as f:
    lines = f.readlines()

label_dict={}

#print lines[0]
#print lines[1]
#print len(lines[1])

for p in range(0,1000):
    image_dict={}
    x_init=''
    for q in range(0,len(lines[p])):
        #print q
        #print lines[1][q]
        if lines[p][q]=='.':
            break
        elif (lines[p][q]=='1' or lines[p][q]=='2' or lines[p][q]=='3' or lines[p][q]=='4' or lines[p][q]=='5' or lines[p][q]=='6' or lines[p][q]=='7' or lines[p][q]=='8' or lines[p][q]=='9' or lines[p][q]=='0'):
            x_init+=lines[p][q]
    x_init=x_init
    print x_init
    
    zzz='"'+lines[p]+'"'
    zzz=zzz[:-3]
    val=zzz.split('\t')
    val2=val[1:]
    l=len(val2)

    #label_init=''
    #for q in range(0,len(lines[p])):
        #if lines[p][q]=='\t':
            #label_init=lines[p][q+1]
            #break
    #print label_init
    for k in range(0,l,2):
        image_dict[val2[k]]=val2[k+1]
    label_dict[x_init]=image_dict
    
print label_dict
    
json_label = json.dumps(label_dict)

with open('/home/ambika/INF_project/label_data_1000.json', 'w') as f:
     json.dump(label_dict, f)
# Out:
# 144114
# 388902
# 171298
# 126260
# 223626
# 422886
# 362219
# 26201
# 561314
# 546687
# 274959
# 323847
# 371322
# 351840
# 306395
# 361055
# 166995
# 75990
# 579457
# 140292
# 436280
# 74711
# 26201
# 572427
# 209419
# 512657
# 531995
# 23033
# 106575
# 561967
# 316429
# 402000
# 184324
# 150623
# 178299
# 1404
# 370765
# 71215
# 342273
# 166837
# 127668
# 412693
# 228467
# 154854
# 318722
# 170267
# 131714
# 521879
# 1700
# 539143
# 100974
# 245513
# 78627
# 105923
# 353970
# 49151
# 228764
# 415856
# 562345
# 185789
# 366031
# 41867
# 78982
# 403054
# 205103
# 566012
# 575219
# 298382
# 192858
# 563665
# 279343
# 436551
# 524775
# 520979
# 383406
# 56651
# 99996
# 196839
# 167486
# 466239
# 441695
# 548780
# 148526
# 31519
# 359710
# 86250
# 469088
# 306135
# 224000
# 327352
# 304063
# 343606
# 363875
# 425925
# 53457
# 257971
# 444804
# 443224
# 379837
# 258311
# 426840
# 231685
# 270893
# 577932
# 32597
# 184994
# 22874
# 368153
# 256197
# 13415
# 511469
# 265001
# 351554
# ...

# %%
import json

# %%
print lines[0]
zzz='"'+lines[0]+'"'
zzz=zzz[:-3]
print zzz
val=zzz.split('\t')
print val
print val[0]

val2=val[1:]
print val2
print len(val2)
# Out:
# /home/ambika/Downloads/CrowdSourcing-Project-master/samples/26201.jpg	fortification	0.100293	residence	0.0344064	puzzle	0.5888196	farm_building	0.0440295
#
# "/home/ambika/Downloads/CrowdSourcing-Project-master/samples/26201.jpg	fortification	0.100293	residence	0.0344064	puzzle	0.5888196	farm_building	0.0440295
# ['"/home/ambika/Downloads/CrowdSourcing-Project-master/samples/26201.jpg', 'fortification', '0.100293', 'residence', '0.0344064', 'puzzle', '0.5888196', 'farm_building', '0.0440295']
# "/home/ambika/Downloads/CrowdSourcing-Project-master/samples/26201.jpg
# ['fortification', '0.100293', 'residence', '0.0344064', 'puzzle', '0.5888196', 'farm_building', '0.0440295']
# 8

# %%
final_path='/home/ambika/INF_project/final_image_paths.txt'
image_list = np.loadtxt(final_path, str)

print(len(image_list))

image_list=list(set(image_list))

print (len(image_list))
# Out:
# 1000
# 1000
